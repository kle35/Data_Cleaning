# %%
import pandas as pd
from datetime import datetime

# %%
data = pd.read_csv('reviews.csv')

# %%
data.head()
# Out:
#             Username     Username_Rating  \
# 0                kcd  4.0 out of 5 stars
# 1               Bast  5.0 out of 5 stars
# 2      Richard Huynh  5.0 out of 5 stars
# 3           mhans311  4.0 out of 5 stars
# 4  Fresh and Felicia  5.0 out of 5 stars
#
#                                      Username_Review  Username_Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...  Verified Purchase
# 1  First off, I havent had a chance to test all f...  Verified Purchase
# 2  I thoroughly enjoy what Sony has to offer in t...  Verified Purchase
# 3  I have used Bose NC700 for the past year, but ...  Verified Purchase
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...  Verified Purchase
#
#              Username_Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                        Username_Date
# ...

# %%
data.count()
# Out:
# Username               664
# Username_Rating        664
# Username_Review        662
# Username_Verified      660
# Username_Usefulness    272
# Username_Date          664
# dtype: int64

# %%
data = data.rename(columns={'Username_Rating': 'Rating'})

# %%
data.head()
# Out:
#             Username              Rating  \
# 0                kcd  4.0 out of 5 stars
# 1               Bast  5.0 out of 5 stars
# 2      Richard Huynh  5.0 out of 5 stars
# 3           mhans311  4.0 out of 5 stars
# 4  Fresh and Felicia  5.0 out of 5 stars
#
#                                      Username_Review  Username_Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...  Verified Purchase
# 1  First off, I havent had a chance to test all f...  Verified Purchase
# 2  I thoroughly enjoy what Sony has to offer in t...  Verified Purchase
# 3  I have used Bose NC700 for the past year, but ...  Verified Purchase
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...  Verified Purchase
#
#              Username_Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                        Username_Date
# ...

# %%
data = data.rename(columns={'Username_Review': 'Review'})

# %%
data.head()
# Out:
#             Username              Rating  \
# 0                kcd  4.0 out of 5 stars
# 1               Bast  5.0 out of 5 stars
# 2      Richard Huynh  5.0 out of 5 stars
# 3           mhans311  4.0 out of 5 stars
# 4  Fresh and Felicia  5.0 out of 5 stars
#
#                                               Review  Username_Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...  Verified Purchase
# 1  First off, I havent had a chance to test all f...  Verified Purchase
# 2  I thoroughly enjoy what Sony has to offer in t...  Verified Purchase
# 3  I have used Bose NC700 for the past year, but ...  Verified Purchase
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...  Verified Purchase
#
#              Username_Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                        Username_Date
# ...

# %%
data = data.rename(columns={'Username_Verified': 'Verified', 'Username_Usefulness': 'Usefulness', 'Username_Date':'Date'})

# %%
data.head()
# Out:
#             Username              Rating  \
# 0                kcd  4.0 out of 5 stars
# 1               Bast  5.0 out of 5 stars
# 2      Richard Huynh  5.0 out of 5 stars
# 3           mhans311  4.0 out of 5 stars
# 4  Fresh and Felicia  5.0 out of 5 stars
#
#                                               Review           Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...  Verified Purchase
# 1  First off, I havent had a chance to test all f...  Verified Purchase
# 2  I thoroughly enjoy what Sony has to offer in t...  Verified Purchase
# 3  I have used Bose NC700 for the past year, but ...  Verified Purchase
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...  Verified Purchase
#
#                       Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                                 Date
# ...

# %%
data['Rating'] = data['Rating'].str[0]

# %%
data.head()
# Out:
#             Username Rating  \
# 0                kcd      4
# 1               Bast      5
# 2      Richard Huynh      5
# 3           mhans311      4
# 4  Fresh and Felicia      5
#
#                                               Review           Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...  Verified Purchase
# 1  First off, I havent had a chance to test all f...  Verified Purchase
# 2  I thoroughly enjoy what Sony has to offer in t...  Verified Purchase
# 3  I have used Bose NC700 for the past year, but ...  Verified Purchase
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...  Verified Purchase
#
#                       Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# ...

# %%
data['Verified'] = data['Verified'].replace({'Verified Purchase':1, '':0})

# %%
data.head()
# Out:
#             Username Rating  \
# 0                kcd      4
# 1               Bast      5
# 2      Richard Huynh      5
# 3           mhans311      4
# 4  Fresh and Felicia      5
#
#                                               Review  Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...       1.0
# 1  First off, I havent had a chance to test all f...       1.0
# 2  I thoroughly enjoy what Sony has to offer in t...       1.0
# 3  I have used Bose NC700 for the past year, but ...       1.0
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...       1.0
#
#                       Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# 1  Reviewed in the United States on January 18, 2023
# ...

# %%
data.tail()
# Out:
#         Username Rating                                             Review  \
# 659         Abby      4  These are awesome headphones. Much lighter the...
# 660        Cathy      1  Beautiful and cute for regular day but for wor...
# 661         Nick      1  I strongly dislike adaptive anc. Why can’t I j...
# 662     Raj Nath      1  entirely disappointed in overall sound quality...
# 663  Music Lover      4  As with previous models these are great for co...
#
#      Verified                     Usefulness  \
# 659       NaN                            NaN
# 660       1.0  One person found this helpful
# 661       1.0    2 people found this helpful
# 662       1.0  One person found this helpful
# 663       NaN                            NaN
#
#                                                   Date
# 659  Reviewed in the United States on February 16, ...
# 660  Reviewed in the United States on September 6, ...
# 661     Reviewed in the United States on July 10, 2022
# ...

# %%
data['Verified'] = data['Verified'].fillna(0)

# %%
data.tail()
# Out:
#         Username Rating                                             Review  \
# 659         Abby      4  These are awesome headphones. Much lighter the...
# 660        Cathy      1  Beautiful and cute for regular day but for wor...
# 661         Nick      1  I strongly dislike adaptive anc. Why can’t I j...
# 662     Raj Nath      1  entirely disappointed in overall sound quality...
# 663  Music Lover      4  As with previous models these are great for co...
#
#      Verified                     Usefulness  \
# 659       0.0                            NaN
# 660       1.0  One person found this helpful
# 661       1.0    2 people found this helpful
# 662       1.0  One person found this helpful
# 663       0.0                            NaN
#
#                                                   Date
# 659  Reviewed in the United States on February 16, ...
# 660  Reviewed in the United States on September 6, ...
# 661     Reviewed in the United States on July 10, 2022
# ...

# %%
data['Verified'] = data['Verified'].astype(int)

# %%
data.head()
# Out:
#             Username Rating  \
# 0                kcd      4
# 1               Bast      5
# 2      Richard Huynh      5
# 3           mhans311      4
# 4  Fresh and Felicia      5
#
#                                               Review  Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...         1
# 1  First off, I havent had a chance to test all f...         1
# 2  I thoroughly enjoy what Sony has to offer in t...         1
# 3  I have used Bose NC700 for the past year, but ...         1
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1
#
#                       Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# 1  Reviewed in the United States on January 18, 2023
# ...

# %%
type(data['Rating'])
# Out:
# pandas.core.series.Series

# %%
data['Rating'] = data['Rating'].astype(int)

# %%
type(data['Rating'])
# Out:
# pandas.core.series.Series

# %%
data.head()
# Out:
#             Username  Rating  \
# 0                kcd       4
# 1               Bast       5
# 2      Richard Huynh       5
# 3           mhans311       4
# 4  Fresh and Felicia       5
#
#                                               Review  Verified  \
# 0  I'm a hobbyist musician and sound engineer of ...         1
# 1  First off, I havent had a chance to test all f...         1
# 2  I thoroughly enjoy what Sony has to offer in t...         1
# 3  I have used Bose NC700 for the past year, but ...         1
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1
#
#                       Usefulness  \
# 0   32 people found this helpful
# 1   53 people found this helpful
# 2   71 people found this helpful
# 3   41 people found this helpful
# 4  768 people found this helpful
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# 1  Reviewed in the United States on January 18, 2023
# ...

# %%
data['Usefulness'].count()
# Out:
# 272

# %%
type(data['Usefulness'])
# Out:
# pandas.core.series.Series

# %%
data['Usefulness'] = data['Usefulness'].str.split(" ").str.get(0)

# %%
data.head()
# Out:
#             Username  Rating  \
# 0                kcd       4
# 1               Bast       5
# 2      Richard Huynh       5
# 3           mhans311       4
# 4  Fresh and Felicia       5
#
#                                               Review  Verified Usefulness  \
# 0  I'm a hobbyist musician and sound engineer of ...         1         32
# 1  First off, I havent had a chance to test all f...         1         53
# 2  I thoroughly enjoy what Sony has to offer in t...         1         71
# 3  I have used Bose NC700 for the past year, but ...         1         41
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1        768
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# 1  Reviewed in the United States on January 18, 2023
# 2  Reviewed in the United States on November 24, ...
# 3  Reviewed in the United States on February 4, 2023
# 4      Reviewed in the United States on May 24, 2022

# %%
data['Usefulness'].isnull().sum()
# Out:
# 392

# %%
data['Usefulness'].fillna(0)
# Out:
# 0       32
# 1       53
# 2       71
# 3       41
# 4      768
#       ...
# 659      0
# 660    One
# 661      2
# 662    One
# 663      0
# Name: Usefulness, Length: 664, dtype: object

# %%
data['Usefulness'].isnull().sum()
# Out:
# 392

# %%
data['Usefulness'].tail()
# Out:
# 659    NaN
# 660    One
# 661      2
# 662    One
# 663    NaN
# Name: Usefulness, dtype: object

# %%
data['Usefulness'] = data['Usefulness'].replace({'One':1})

# %%
data['Usefulness'].tail()
# Out:
# 659    NaN
# 660      1
# 661      2
# 662      1
# 663    NaN
# Name: Usefulness, dtype: object

# %%
data['Usefulness'] = data['Usefulness'].fillna(0)

# %%
data['Usefulness'].tail()
# Out:
# 659    0
# 660    1
# 661    2
# 662    1
# 663    0
# Name: Usefulness, dtype: object

# %%
data.tail()
# Out:
#         Username  Rating                                             Review  \
# 659         Abby       4  These are awesome headphones. Much lighter the...
# 660        Cathy       1  Beautiful and cute for regular day but for wor...
# 661         Nick       1  I strongly dislike adaptive anc. Why can’t I j...
# 662     Raj Nath       1  entirely disappointed in overall sound quality...
# 663  Music Lover       4  As with previous models these are great for co...
#
#      Verified Usefulness                                               Date
# 659         0          0  Reviewed in the United States on February 16, ...
# 660         1          1  Reviewed in the United States on September 6, ...
# 661         1          2     Reviewed in the United States on July 10, 2022
# 662         1          1   Reviewed in the United States on August 25, 2022
# 663         0          0  Reviewed in the United States on January 27, 2023

# %%
data.count()
# Out:
# Username      664
# Rating        664
# Review        662
# Verified      664
# Usefulness    664
# Date          664
# dtype: int64

# %%
data['Rating'].isnull().sum()
# Out:
# 0

# %%
data.head()
# Out:
#             Username  Rating  \
# 0                kcd       4
# 1               Bast       5
# 2      Richard Huynh       5
# 3           mhans311       4
# 4  Fresh and Felicia       5
#
#                                               Review  Verified Usefulness  \
# 0  I'm a hobbyist musician and sound engineer of ...         1         32
# 1  First off, I havent had a chance to test all f...         1         53
# 2  I thoroughly enjoy what Sony has to offer in t...         1         71
# 3  I have used Bose NC700 for the past year, but ...         1         41
# 4  I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1        768
#
#                                                 Date
# 0  Reviewed in the United States on February 10, ...
# 1  Reviewed in the United States on January 18, 2023
# 2  Reviewed in the United States on November 24, ...
# 3  Reviewed in the United States on February 4, 2023
# 4      Reviewed in the United States on May 24, 2022

# %%
data = data.rename(columns={'Date': 'Country'})

# %%
data
# Out:
#               Username  Rating  \
# 0                  kcd       4
# 1                 Bast       5
# 2        Richard Huynh       5
# 3             mhans311       4
# 4    Fresh and Felicia       5
# ..                 ...     ...
# 659               Abby       4
# 660              Cathy       1
# 661               Nick       1
# 662           Raj Nath       1
# 663        Music Lover       4
#
#                                                 Review  Verified Usefulness  \
# 0    I'm a hobbyist musician and sound engineer of ...         1         32
# 1    First off, I havent had a chance to test all f...         1         53
# 2    I thoroughly enjoy what Sony has to offer in t...         1         71
# 3    I have used Bose NC700 for the past year, but ...         1         41
# 4    I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1        768
# ..                                                 ...       ...        ...
# ...

# %%
data['Date'] = data['Country'].str.split(" ").str[-3:].str.join(" ")

# %%
data
# Out:
#               Username  Rating  \
# 0                  kcd       4
# 1                 Bast       5
# 2        Richard Huynh       5
# 3             mhans311       4
# 4    Fresh and Felicia       5
# ..                 ...     ...
# 659               Abby       4
# 660              Cathy       1
# 661               Nick       1
# 662           Raj Nath       1
# 663        Music Lover       4
#
#                                                 Review  Verified Usefulness  \
# 0    I'm a hobbyist musician and sound engineer of ...         1         32
# 1    First off, I havent had a chance to test all f...         1         53
# 2    I thoroughly enjoy what Sony has to offer in t...         1         71
# 3    I have used Bose NC700 for the past year, but ...         1         41
# 4    I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1        768
# ..                                                 ...       ...        ...
# ...

# %%
type(data["Date"])
# Out:
# pandas.core.series.Series

# %%
data["Date"] = pd.to_datetime(data["Date"])

# %%
type(data["Date"])
# Out:
# pandas.core.series.Series

# %%
data['Country'] = data['Country'].str.split(" ").str[3:5].str.join(" ")

# %%
data
# Out:
#               Username  Rating  \
# 0                  kcd       4
# 1                 Bast       5
# 2        Richard Huynh       5
# 3             mhans311       4
# 4    Fresh and Felicia       5
# ..                 ...     ...
# 659               Abby       4
# 660              Cathy       1
# 661               Nick       1
# 662           Raj Nath       1
# 663        Music Lover       4
#
#                                                 Review  Verified Usefulness  \
# 0    I'm a hobbyist musician and sound engineer of ...         1         32
# 1    First off, I havent had a chance to test all f...         1         53
# 2    I thoroughly enjoy what Sony has to offer in t...         1         71
# 3    I have used Bose NC700 for the past year, but ...         1         41
# 4    I own Sony’s WH-1000 XM4s and the Bose 700s, t...         1        768
# ..                                                 ...       ...        ...
# ...

# %%
time_max = data['Date'].max()
time_max
# Out:
# Timestamp('2023-02-23 00:00:00')

# %%
time_min = data['Date'].min()
time_min
# Out:
# Timestamp('2022-05-20 00:00:00')

# %%
time_range = time_max - time_min
time_range
# Out:
# Timedelta('279 days 00:00:00')

# %%
interesting_count = data['Country'][data['Country'] != 'United States'].count()
interesting_count
# Out:
# 0
